# %% [markdown]
# # Tweaking the Features
#
# Neural net tuning brought us from 72.87% to 73.42% accuracy, but we're still looking for 75% accuracy. Here, we exhaustively check all combinations of features, to see which ones give the highest accuracy.

# %%
# Import our dependencies
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler
import pandas as pd
import tensorflow as tf
import itertools

# %%
def create_app_df(cols) -> pd.DataFrame:
    #  Import and read the charity_data.csv.
    #application_df = pd.read_csv("https://static.bc-edx.com/data/dl-1-2/m21/lms/starter/charity_data.csv")
    application_df = pd.read_csv("Data/charity_data.csv")

    # Choose a cutoff value and create a list of application types to be replaced
    for app in application_df["APPLICATION_TYPE"].value_counts().index[8:]:
        application_df['APPLICATION_TYPE'] = application_df['APPLICATION_TYPE'].replace(app,"Other")

    # Choose a cutoff value and create a list of classifications to be replaced
    for cls in application_df["CLASSIFICATION"].value_counts().index[5:]:
        application_df['CLASSIFICATION'] = application_df['CLASSIFICATION'].replace(cls,"Other")

    application_df = application_df[[*cols, "IS_SUCCESSFUL"]]

    application_df = pd.get_dummies(application_df)
    return application_df

# %%
def get_column_combos() -> []:
    all_cols = ["APPLICATION_TYPE","AFFILIATION","CLASSIFICATION","USE_CASE","ORGANIZATION","STATUS","INCOME_AMT","SPECIAL_CONSIDERATIONS","ASK_AMT"]
    for combo_count in range(1,len(all_cols)):
        for combo in itertools.combinations(all_cols, combo_count):
            yield list(combo)

# %%
def create_model(num_cols):
    # Define the model - deep neural net, i.e., the number of input features and hidden nodes for each layer.
    # Use most efficient neural network from tuning notebook. Won't always be most efficient, but it gives us a chance
    # 0 - selu 6, 1 - selu 13, 2 - tanh 7, output - sigmoid 1
    model = tf.keras.models.Sequential()
    model.add(tf.keras.layers.Dense(units=6, activation="selu", input_dim=num_cols))
    model.add(tf.keras.layers.Dense(units=13, activation="selu"))
    model.add(tf.keras.layers.Dense(units=7, activation="tanh"))
    model.add(tf.keras.layers.Dense(units=1, activation="sigmoid"))

    # Compile the model
    model.compile(loss="binary_crossentropy", optimizer="adam", metrics=["accuracy"])
    
    return model

# %%
# Beware, this can take almost 6 hours to run!
all_model_stats = []

for col_combo in get_column_combos():
    application_df = create_app_df(col_combo)

    model_summary = { 'cols': application_df.columns }

    # Split our preprocessed data into our features and target arrays
    features = application_df.drop("IS_SUCCESSFUL", axis=1)
    target = application_df["IS_SUCCESSFUL"]

    # Split the preprocessed data into a training and testing dataset
    X_train, X_test, y_train, y_test = train_test_split(features, target, random_state=1)

    # Create a StandardScaler instance
    # Fit the StandardScaler
    X_scaler = StandardScaler().fit(X_train)

    # Scale the data
    X_train_scaled = X_scaler.transform(X_train)
    X_test_scaled = X_scaler.transform(X_test)

    model = create_model(len(features.columns))

    # Train the model
    history = model.fit(
        X_train_scaled,
        y_train,
        epochs=34,
        verbose=0
        )

    model_loss, model_accuracy = model.evaluate(X_test_scaled,y_test,verbose=2)
    model_summary["accuracy"] = model_accuracy
    model_summary["loss"] = model_loss

    all_model_stats.append(model_summary)
# Out:
# 268/268 - 0s - loss: 0.6677 - accuracy: 0.5720 - 426ms/epoch - 2ms/step
# 268/268 - 0s - loss: 0.6185 - accuracy: 0.6917 - 408ms/epoch - 2ms/step
# 268/268 - 0s - loss: 0.6719 - accuracy: 0.5784 - 416ms/epoch - 2ms/step
# 268/268 - 0s - loss: 0.6902 - accuracy: 0.5354 - 414ms/epoch - 2ms/step
# 268/268 - 0s - loss: 0.6720 - accuracy: 0.6000 - 413ms/epoch - 2ms/step
# 268/268 - 0s - loss: 0.6914 - accuracy: 0.5292 - 417ms/epoch - 2ms/step
# 268/268 - 0s - loss: 0.6877 - accuracy: 0.5346 - 412ms/epoch - 2ms/step
# 268/268 - 0s - loss: 0.6915 - accuracy: 0.5292 - 411ms/epoch - 2ms/step
# 268/268 - 0s - loss: 0.6907 - accuracy: 0.5342 - 411ms/epoch - 2ms/step
# 268/268 - 0s - loss: 0.5851 - accuracy: 0.7191 - 408ms/epoch - 2ms/step
# 268/268 - 0s - loss: 0.6462 - accuracy: 0.6170 - 421ms/epoch - 2ms/step
# 268/268 - 0s - loss: 0.6613 - accuracy: 0.5785 - 420ms/epoch - 2ms/step
# 268/268 - 0s - loss: 0.6477 - accuracy: 0.6251 - 425ms/epoch - 2ms/step
# 268/268 - 0s - loss: 0.6678 - accuracy: 0.5720 - 421ms/epoch - 2ms/step
# 268/268 - 0s - loss: 0.6637 - accuracy: 0.5771 - 416ms/epoch - 2ms/step
# 268/268 - 0s - loss: 0.6683 - accuracy: 0.5720 - 415ms/epoch - 2ms/step
# 268/268 - 0s - loss: 0.
ms/epoch - 2ms/step
# 268/268 - 0s - loss: 0.6134 - accuracy: 0.6560 - 424ms/epoch - 2ms/step
# 268/268 - 0s - loss: 0.6141 - accuracy: 0.6569 - 416ms/epoch - 2ms/step
# 268/268 - 0s - loss: 0.6160 - accuracy: 0.6557 - 411ms/epoch - 2ms/step
# 268/268 - 0s - loss: 0.6104 - accuracy: 0.6587 - 414ms/epoch - 2ms/step
# 268/268 - 0s - loss: 0.6331 - accuracy: 0.6278 - 416ms/epoch - 2ms/step
# 268/268 - 0s - loss: 0.6176 - accuracy: 0.6531 - 416ms/epoch - 2ms/step
# 268/268 - 0s - loss: 0.6396 - accuracy: 0.6349 - 421ms/epoch - 2ms/step
# 268/268 - 0s - loss: 0.5783 - accuracy: 0.7044 - 410ms/epoch - 2ms/step
# 268/268 - 4s - loss: 0.5798 - accuracy: 0.7073 - 4s/epoch - 16ms/step
# 268/268 - 0s - loss: 0.5836 - accuracy: 0.7059 - 417ms/epoch - 2ms/step
# 268/268 - 0s - loss: 0.5765 - accuracy: 0.7101 - 410ms/epoch - 2ms/step
# 268/268 - 0s - loss: 0.5962 - accuracy: 0.6971 - 415ms/epoch - 2ms/step
# 268/268 - 0s - loss: 0.5854 - accuracy: 0.7010 - 417ms/epoch - 2ms/step
# 268/268 - 0s - loss: 0.5991 - accuracy: 0.7001 - 423ms/epoch - 2ms/step
# 268/268 - 0s - loss: 0.6321 - accuracy: 0.6374 - 416ms/epoch - 2ms/step
# 268/268 - 0s - loss: 0.5561 - accuracy: 0.7276 - 416ms/epoch - 2ms/step
# 268/268 - 0s - loss: 0.5549 - accuracy: 0.7278 - 420ms/epoch - 2ms/step
# 268/268 - 0s - loss: 0.5608 - accuracy: 0.7270 - 418ms/epoch - 2ms/step
# 268/268 - 0s - loss: 0.5521 - accuracy: 0.7282 - 419ms/epoch - 2ms/step
# 268/268 - 0s - loss: 0.5614 - accuracy: 0.7250 - 414ms/epoch - 2ms/step
# 268/268 - 0s - loss: 0.5570 - accuracy: 0.7299 - 422ms/epoch - 2ms/step
# 268/268 - 0s - loss: 0.5703 - accuracy: 0.7248 - 417ms/epoch - 2ms/step
# 268/268 - 0s - loss: 0.6126 - accuracy: 0.6527 - 417ms/epoch - 2ms/step
# 268/268 - 0s - loss: 0.5770 - accuracy: 0.7045 - 420ms/epoch - 2ms/step

# %%
all_cols = ["APPLICATION_TYPE","AFFILIATION","CLASSIFICATION","USE_CASE","ORGANIZATION","STATUS","INCOME_AMT","SPECIAL_CONSIDERATIONS","ASK_AMT"]

# Print all summaries, in order of descending accuracy
for i, model_stats in enumerate(sorted(all_model_stats, key=lambda x: x["accuracy"], reverse=True)):
    cols = [col for col in all_cols if col in [col for x in model_stats["cols"] if col in x]]
    print(f'Number {i+1} most effective\nColumns: {", ".join(cols)}\n{model_stats["accuracy"]}\n{model_stats["loss"]}\n--------------')
# Out:
# Number 1 most effective
# Columns: APPLICATION_TYPE, AFFILIATION, CLASSIFICATION, ORGANIZATION, INCOME_AMT
# 0.7318950295448303
# 0.5562520027160645
# --------------
# Number 2 most effective
# Columns: APPLICATION_TYPE, AFFILIATION, CLASSIFICATION, ORGANIZATION, INCOME_AMT, ASK_AMT
# 0.7302623987197876
# 0.5550990700721741
# --------------
# Number 3 most effective
# Columns: APPLICATION_TYPE, AFFILIATION, CLASSIFICATION, ORGANIZATION, INCOME_AMT, SPECIAL_CONSIDERATIONS, ASK_AMT
# 0.729912519454956
# 0.5551552772521973
# --------------
# Number 4 most effective
# Columns: APPLICATION_TYPE, AFFILIATION, CLASSIFICATION, ORGANIZATION, STATUS, INCOME_AMT, SPECIAL_CONSIDERATIONS, ASK_AMT
# 0.729912519454956
# 0.5570317506790161
# --------------
# Number 5 most effective
# Columns: APPLICATION_TYPE, AFFILIATION, CLASSIFICATION, ORGANIZATION, INCOME_AMT, SPECIAL_CONSIDERATIONS
# 0.7295626997947693
# 0.5575858354568481
# --------------
# Number 6 most effective
# Columns: APPLICATION_TYPE, AFFILIATION, CLASSIFICATION, USE_CASE, ORGANIZATION, INCOME_AMT, ASK_AMT
# 0.7293294668197632
# 0.5538225769996643
# --------------
# Number 7 most effective
# Columns: APPLICATION_TYPE, AFFILIATION, CLASSIFICATION, USE_CASE, ORGANIZATION, INCOME_AMT
# 0.7292128205299377
# 0.5530814528465271
# --------------
# Number 8 most effective
# Columns: APPLICATION_TYPE, AFFILIATION, CLASSIFICATION, ORGANIZATION, STATUS, SPECIAL_CONSIDERATIONS, ASK_AMT
# 0.7292128205299377
# 0.5608330368995667
# --------------
# Number 9 most effective
# Columns: APPLICATION_TYPE, AFFILIATION, CLASSIFICATION, USE_CASE, ORGANIZATION, INCOME_AMT, SPECIAL_CONSIDERATIONS
# 0.7289795875549316
# 0.5545604825019836
# --------------
# Number 10 most effective
# Columns: APPLICATION_TYPE, AFFILIATION, CLASSIFICATION, ORGANIZATION, ASK_AMT
# 0.728863000869751
# 0.5626291036605835
# --------------
# Number 11 most effective
# Columns: APPLICATION_TYPE, AFFILIATION, CLASSIFICATION, ORGANIZATION, STATUS, INCOME_AMT, SPECIAL_CONSIDERATIONS
# 0.7285131216049194
# 0.5562204122543335
# --------------
# Number 12 most effective
# Columns: APPLICATION_TYPE, AFFILIATION, CLASSIFICATION, USE_CASE, ORGANIZATION, INCOME_AMT, SPECIAL_CONSIDERATIONS, ASK_AMT
# 0.7281632423400879
# 0.5521198511123657
# --------------
# Number 13 most effective
# Columns: APPLICATION_TYPE, AFFILIATION, CLASSIFICATION, USE_CASE, ORGANIZATION, STATUS, INCOME_AMT
# 0.7280466556549072
# 0.5535193681716919
# --------------
# Number 14 most effective
# Columns: APPLICATION_TYPE, AFFILIATION, CLASSIFICATION, USE_CASE, ORGANIZATION, STATUS, INCOME_AMT, ASK_AMT
# 0.7278134226799011
# 0.5548959374427795
# --------------
# Number 15 most effective
# Columns: APPLICATION_TYPE, AFFILIATION, CLASSIFICATION, ORGANIZATION, STATUS, ASK_AMT
# 0.727580189704895
# 0.5603300333023071
# --------------
# Number 16 most effective
# Columns: APPLICATION_TYPE, AFFILIATION, CLASSIFICATION, USE_CASE, ORGANIZATION, STATUS, INCOME_AMT, SPECIAL_CONSIDERATIONS
# 0.727580189704895
# 0.5560619831085205
# --------------
# Number 17 most effective
# Columns: APPLICATION_TYPE, AFFILIATION, CLASSIFICATION, ORGANIZATION, STATUS, INCOME_AMT
# 0.7274635434150696
# 0.5585329532623291
# --------------
# Number 18 most effective
# Columns: APPLICATION_TYPE, AFFILIATION, CLASSIFICATION, USE_CASE, ORGANIZATION
# 0.7273469567298889
# 0.5609868764877319
# --------------
# Number 19 most effective
# Columns: APPLICATION_TYPE, AFFILIATION, CLASSIFICATION, STATUS, INCOME_AMT, SPECIAL_CONSIDERATIONS
# 0.7272303104400635
# 0.5637837648391724
# --------------
# Number 20 most effective
# Columns: APPLICATION_TYPE, AFFILIATION, CLASSIFICATION, INCOME_AMT
# 0.7271137237548828
# 0.5643402934074402
# --------------
# Number 21 most effective
# Columns: APPLICATION_TYPE, AFFILIATION, CLASSIFICATION, USE_CASE, ORGANIZATION, STATUS, SPECIAL_CONSIDERATIONS, ASK_AMT
# 0.7269970774650574
# 0.5607803463935852
# --------------
# Number 22 most effective
# Columns: APPLICATION_TYPE, AFFILIATION, CLASSIFICATION, INCOME_AMT, SPECIAL_CONSIDERATIONS
# 0.7267638444900513
# 0.5643102526664734
# --------------
# Number 23 most effective
# Columns: APPLICATION_TYPE, AFFILIATION, CLASSIFICATION, INCOME_AMT, ASK_AMT
# 0.7267638444900513
# 0.5634980201721191
# --------------
# Number 24 most effective
# Columns: APPLICATION_TYPE, AFFILIATION, CLASSIFICATION, STATUS, INCOME_AMT, ASK_AMT
# 0.7267638444900513
# 0.5645650625228882
# --------------
# Number 25 most effective
# Columns: APPLICATION_TYPE, AFFILIATION, CLASSIFICATION, USE_CASE, ORGANIZATION, STATUS, ASK_AMT
# 0.7264139652252197
# 0.5641197562217712
# --------------
# Number 26 most effective
# Columns: APPLICATION_TYPE, AFFILIATION, CLASSIFICATION, ORGANIZATION
# 0.7262973785400391
# 0.5642369389533997
# --------------
# Number 27 most effective
# Columns: APPLICATION_TYPE, AFFILIATION, CLASSIFICATION, ORGANIZATION, STATUS, INCOME_AMT, ASK_AMT
# 0.726064145565033
# 0.5637468099594116
# --------------
# Number 28 most effective
# Columns: APPLICATION_TYPE, AFFILIATION, ORGANIZATION, INCOME_AMT, ASK_AMT
# 0.7259474992752075
# 0.5724031329154968
# --------------
# Number 29 most effective
# Columns: APPLICATION_TYPE, AFFILIATION, CLASSIFICATION, ORGANIZATION, STATUS
# 0.7257142663002014
# 0.5651302933692932
# --------------
# Number 30 most effective
# Columns: APPLICATION_TYPE, AFFILIATION, ORGANIZATION, STATUS, INCOME_AMT
# 0.7257142663002014
# 0.572340190410614
# --------------
# Number 31 most effective
# Columns: APPLICATION_TYPE, AFFILIATION, CLASSIFICATION, USE_CASE, ORGANIZATION, SPECIAL_CONSIDERATIONS
# 0.7257142663002014
# 0.5614538788795471
# --------------
# Number 32 most effective
# Columns: APPLICATION_TYPE, AFFILIATION, CLASSIFICATION, USE_CASE, ORGANIZATION, ASK_AMT
# 0.7257142663002014
# 0.5601999163627625
# --------------
# Number 33 most effective
# Columns: APPLICATION_TYPE, AFFILIATION, USE_CASE, ORGANIZATION, INCOME_AMT, ASK_AMT
# 0.7255976796150208
# 0.5703458786010742
# --------------
# Number 34 most effective
# Columns: APPLICATION_TYPE, AFFILIATION, CLASSIFICATION, USE_CASE, ORGANIZATION, STATUS, SPECIAL_CONSIDERATIONS
# 0.7255976796150208
# 0.5616458058357239
# --------------
# Number 35 most effective
# Columns: APPLICATION_TYPE, AFFILIATION, USE_CASE, ORGANIZATION, STATUS, INCOME_AMT, SPECIAL_CONSIDERATIONS
# 0.7254810333251953
# 0.5706217288970947
# --------------
# Number 36 most effective
# Columns: APPLICATION_TYPE, AFFILIATION, SPECIAL_CONSIDERATIONS, ASK_AMT
# 0.7253644466400146
# 0.5809682011604309
# --------------
# Number 37 most effective
# Columns: APPLICATION_TYPE, AFFILIATION, ORGANIZATION, ASK_AMT
# 0.7252478003501892
# 0.5741499662399292
# --------------
# Number 38 most effective
# Columns: APPLICATION_TYPE, AFFILIATION, CLASSIFICATION, ORGANIZATION, SPECIAL_CONSIDERATIONS
# 0.7250145673751831
# 0.5656217932701111
# --------------
# Number 39 most effective
# Columns: APPLICATION_TYPE, AFFILIATION, CLASSIFICATION, ORGANIZATION, STATUS, SPECIAL_CONSIDERATIONS
# 0.7250145673751831
# 0.5644164681434631
# --------------
# Number 40 most effective
# Columns: APPLICATION_TYPE, AFFILIATION, USE_CASE, ORGANIZATION, INCOME_AMT, SPECIAL_CONSIDERATIONS
# 0.7250145673751831
# 0.5710545182228088
# --------------
# Number 41 most effective
# Columns: APPLICATION_TYPE, AFFILIATION, CLASSIFICATION, USE_CASE, ORGANIZATION, SPECIAL_CONSIDERATIONS, ASK_AMT
# 0.7250145673751831
# 0.5606082081794739
# --------------
# Number 42 most effective
# Columns: APPLICATION_TYPE, AFFILIATION, CLASSIFICATION, USE_CASE, STATUS, INCOME_AMT, SPECIAL_CONSIDERATIONS, ASK_AMT
# 0.7250145673751831
# 0.561439573764801
# --------------
# Number 43 most effective
# Columns: APPLICATION_TYPE, AFFILIATION, USE_CASE, ORGANIZATION, STATUS, INCOME_AMT
# 0.7248979806900024
# 0.5721673369407654
# --------------
# Number 44 most effective
# Columns: APPLICATION_TYPE, AFFILIATION, ORGANIZATION, STATUS, INCOME_AMT, SPECIAL_CONSIDERATIONS, ASK_AMT
# 0.7248979806900024
# 0.5727883577346802
# --------------
# Number 45 most effective
# Columns: APPLICATION_TYPE, AFFILIATION, ORGANIZATION, INCOME_AMT, SPECIAL_CONSIDERATIONS
# 0.724781334400177
# 0.5736933350563049
# --------------
# Number 46 most effective
# Columns: APPLICATION_TYPE, AFFILIATION, STATUS, SPECIAL_CONSIDERATIONS, ASK_AMT
# 0.724781334400177
# 0.5798357725143433
# --------------
# Number 47 most effective
# Columns: APPLICATION_TYPE, AFFILIATION, CLASSIFICATION, USE_CASE, INCOME_AMT, SPECIAL_CONSIDERATIONS
# 0.724781334400177
# 0.56304931640625
# --------------
# Number 48 most effective
# Columns: APPLICATION_TYPE, AFFILIATION, ORGANIZATION, INCOME_AMT, SPECIAL_CONSIDERATIONS, ASK_AMT
# 0.724781334400177
# 0.5731544494628906
# --------------
# Number 49 most effective
# Columns: APPLICATION_TYPE, AFFILIATION, USE_CASE, ORGANIZATION, STATUS, INCOME_AMT, SPECIAL_CONSIDERATIONS, ASK_AMT
# 0.724781334400177
# 0.5702831745147705
# --------------
# Number 50 most effective
# Columns: APPLICATION_TYPE, AFFILIATION, ORGANIZATION, INCOME_AMT
# 0.7246647477149963
# 0.5742120146751404
# --------------
# Number 51 most effective
# Columns: APPLICATION_TYPE, AFFILIATION, ORGANIZATION, STATUS, SPECIAL_CONSIDERATIONS, ASK_AMT
# 0.7245481014251709
# 0.5762289762496948
# --------------
# Number 52 most effective
# Columns: APPLICATION_TYPE, AFFILIATION, INCOME_AMT, ASK_AMT
# 0.7243148684501648
# 0.578262209892273
# --------------
# Number 53 most effective
# Columns: APPLICATION_TYPE, AFFILIATION, ORGANIZATION, STATUS, ASK_AMT
# 0.7243148684501648
# 0.5830790996551514
# --------------
# Number 54 most effective
# Columns: APPLICATION_TYPE, AFFILIATION, CLASSIFICATION, USE_CASE, INCOME_AMT, ASK_AMT
# 0.7243148684501648
# 0.5624600052833557
# --------------
# Number 55 most effective
# Columns: APPLICATION_TYPE, AFFILIATION, CLASSIFICATION, INCOME_AMT, SPECIAL_CONSIDERATIONS, ASK_AMT
# 0.7243148684501648
# 0.56379634141922
# --------------
# Number 56 most effective
# Columns: APPLICATION_TYPE, AFFILIATION, ORGANIZATION, STATUS, INCOME_AMT, SPECIAL_CONSIDERATIONS
# 0.7243148684501648
# 0.574701189994812
# --------------
# Number 57 most effective
# Columns: APPLICATION_TYPE, AFFILIATION, CLASSIFICATION, USE_CASE, INCOME_AMT, SPECIAL_CONSIDERATIONS, ASK_AMT
# 0.7243148684501648
# 0.5621148943901062
# --------------
# Number 58 most effective
# Columns: APPLICATION_TYPE, AFFILIATION, INCOME_AMT, SPECIAL_CONSIDERATIONS, ASK_AMT
# 0.7241982221603394
# 0.5784560441970825
# --------------
# Number 59 most effective
# Columns: APPLICATION_TYPE, AFFILIATION, CLASSIFICATION, USE_CASE, ORGANIZATION, STATUS
# 0.7241982221603394
# 0.5618526935577393
# --------------
# Number 60 most effective
# Columns: APPLICATION_TYPE, AFFILIATION, CLASSIFICATION, USE_CASE, STATUS, INCOME_AMT
# 0.7241982221603394
# 0.5622120499610901
# --------------
# Number 61 most effective
# Columns: APPLICATION_TYPE, AFFILIATION, CLASSIFICATION, STATUS, INCOME_AMT
# 0.7240816354751587
# 0.563252329826355
# --------------
# Number 62 most effective
# Columns: APPLICATION_TYPE, AFFILIATION, ORGANIZATION, STATUS, INCOME_AMT, ASK_AMT
# 0.7240816354751587
# 0.5721824765205383
# --------------
# Number 63 most effective
# Columns: APPLICATION_TYPE, AFFILIATION, STATUS, INCOME_AMT, ASK_AMT
# 0.7238484025001526
# 0.578334629535675
# --------------
# Number 64 most effective
# Columns: APPLICATION_TYPE, AFFILIATION, CLASSIFICATION, ASK_AMT
# 0.7237317562103271
# 0.5700829029083252
# --------------
# Number 65 most effective
# Columns: APPLICATION_TYPE, AFFILIATION, CLASSIFICATION, STATUS, INCOME_AMT, SPECIAL_CONSIDERATIONS, ASK_AMT
# 0.7237317562103271
# 0.5654774904251099
# --------------
# Number 66 most effective
# Columns: APPLICATION_TYPE, AFFILIATION, INCOME_AMT, SPECIAL_CONSIDERATIONS
# 0.7236151695251465
# 0.5775661468505859
# --------------
# Number 67 most effective
# Columns: APPLICATION_TYPE, AFFILIATION, CLASSIFICATION, USE_CASE, INCOME_AMT
# 0.7236151695251465
# 0.5602013468742371
# --------------
# Number 68 most effective
# Columns: APPLICATION_TYPE, AFFILIATION, CLASSIFICATION, USE_CASE, STATUS, INCOME_AMT, ASK_AMT
# 0.7236151695251465
# 0.5626732707023621
# --------------
# Number 69 most effective
# Columns: APPLICATION_TYPE, AFFILIATION, CLASSIFICATION, SPECIAL_CONSIDERATIONS, ASK_AMT
# 0.7233819365501404
# 0.5743179321289062
# --------------
# Number 70 most effective
# Columns: APPLICATION_TYPE, AFFILIATION, USE_CASE, ORGANIZATION, INCOME_AMT
# 0.7233819365501404
# 0.5704349875450134
# --------------
# Number 71 most effective
# Columns: APPLICATION_TYPE, AFFILIATION, USE_CASE, INCOME_AMT, ASK_AMT
# 0.7233819365501404
# 0.5784324407577515
# --------------
# Number 72 most effective
# Columns: APPLICATION_TYPE, AFFILIATION, ORGANIZATION, SPECIAL_CONSIDERATIONS, ASK_AMT
# 0.7233819365501404
# 0.5766151547431946
# --------------
# Number 73 most effective
# Columns: APPLICATION_TYPE, AFFILIATION, USE_CASE, ORGANIZATION, SPECIAL_CONSIDERATIONS, ASK_AMT
# 0.7233819365501404
# 0.5750487446784973
# --------------
# Number 74 most effective
# Columns: APPLICATION_TYPE, AFFILIATION, STATUS, INCOME_AMT, SPECIAL_CONSIDERATIONS, ASK_AMT
# 0.7233819365501404
# 0.5776907205581665
# --------------
# Number 75 most effective
# Columns: APPLICATION_TYPE, AFFILIATION, USE_CASE, INCOME_AMT, SPECIAL_CONSIDERATIONS
# 0.7232652902603149
# 0.5758897066116333
# --------------
# Number 76 most effective
# Columns: APPLICATION_TYPE, AFFILIATION, USE_CASE, ORGANIZATION, STATUS, SPECIAL_CONSIDERATIONS, ASK_AMT
# 0.7232652902603149
# 0.5760415196418762
# --------------
# Number 77 most effective
# Columns: APPLICATION_TYPE, AFFILIATION, INCOME_AMT
# 0.7231487035751343
# 0.5780435800552368
# --------------
# Number 78 most effective
# Columns: APPLICATION_TYPE, AFFILIATION, ASK_AMT
# 0.7230320572853088
# 0.5797975063323975
# --------------
# Number 79 most effective
# Columns: APPLICATION_TYPE, AFFILIATION, STATUS, ASK_AMT
# 0.7230320572853088
# 0.5809097290039062
# --------------
# Number 80 most effective
# Columns: APPLICATION_TYPE, AFFILIATION, USE_CASE, ORGANIZATION, ASK_AMT
# 0.7230320572853088
# 0.5752214193344116
# --------------
# Number 81 most effective
# Columns: APPLICATION_TYPE, AFFILIATION, USE_CASE, ORGANIZATION, STATUS, ASK_AMT
# 0.7230320572853088
# 0.5742958784103394
# --------------
# Number 82 most effective
# Columns: APPLICATION_TYPE, AFFILIATION, USE_CASE, STATUS, INCOME_AMT, SPECIAL_CONSIDERATIONS, ASK_AMT
# 0.7230320572853088
# 0.577965497970581
# --------------
# Number 83 most effective
# Columns: APPLICATION_TYPE, AFFILIATION, USE_CASE, INCOME_AMT
# 0.7229154706001282
# 0.5772470831871033
# --------------
# Number 84 most effective
# Columns: APPLICATION_TYPE, AFFILIATION, CLASSIFICATION, STATUS, ASK_AMT
# 0.7229154706001282
# 0.5711471438407898
# --------------
# Number 85 most effective
# Columns: APPLICATION_TYPE, AFFILIATION, STATUS, INCOME_AMT
# 0.7227988243103027
# 0.5777100324630737
# --------------
# Number 86 most effective
# Columns: APPLICATION_TYPE, AFFILIATION, CLASSIFICATION, USE_CASE, ASK_AMT
# 0.7227988243103027
# 0.5680766701698303
# --------------
# Number 87 most effective
# Columns: APPLICATION_TYPE, AFFILIATION, USE_CASE, STATUS, ASK_AMT
# 0.7227988243103027
# 0.5806862711906433
# --------------
# Number 88 most effective
# Columns: APPLICATION_TYPE, AFFILIATION, STATUS, INCOME_AMT, SPECIAL_CONSIDERATIONS
# 0.7227988243103027
# 0.5790042877197266
# --------------
# Number 89 most effective
# Columns: APPLICATION_TYPE, AFFILIATION, CLASSIFICATION, STATUS, SPECIAL_CONSIDERATIONS, ASK_AMT
# 0.7227988243103027
# 0.5713812112808228
# --------------
# Number 90 most effective
# Columns: APPLICATION_TYPE, AFFILIATION, USE_CASE, INCOME_AMT, SPECIAL_CONSIDERATIONS, ASK_AMT
# 0.7227988243103027
# 0.5772884488105774
# --------------
# Number 91 most effective
# Columns: APPLICATION_TYPE, AFFILIATION, CLASSIFICATION, USE_CASE, STATUS, INCOME_AMT, SPECIAL_CONSIDERATIONS
# 0.7227988243103027
# 0.563543438911438
# --------------
# Number 92 most effective
# Columns: APPLICATION_TYPE, AFFILIATION, USE_CASE, ORGANIZATION, INCOME_AMT, SPECIAL_CONSIDERATIONS, ASK_AMT
# 0.7227988243103027
# 0.5704032182693481
# --------------
# Number 93 most effective
# Columns: APPLICATION_TYPE, AFFILIATION, USE_CASE, SPECIAL_CONSIDERATIONS, ASK_AMT
# 0.7226822376251221
# 0.5795972347259521
# --------------
# Number 94 most effective
# Columns: APPLICATION_TYPE, AFFILIATION, CLASSIFICATION, ORGANIZATION, SPECIAL_CONSIDERATIONS, ASK_AMT
# 0.7225655913352966
# 0.5654682517051697
# --------------
# Number 95 most effective
# Columns: APPLICATION_TYPE, AFFILIATION, USE_CASE, STATUS, INCOME_AMT, ASK_AMT
# 0.7225655913352966
# 0.5781443119049072
# --------------
# Number 96 most effective
# Columns: APPLICATION_TYPE, AFFILIATION, USE_CASE, ORGANIZATION, STATUS, INCOME_AMT, ASK_AMT
# 0.7225655913352966
# 0.5716978907585144
# --------------
# Number 97 most effective
# Columns: APPLICATION_TYPE, AFFILIATION, USE_CASE, STATUS, INCOME_AMT
# 0.7222157716751099
# 0.5765470862388611
# --------------
# Number 98 most effective
# Columns: APPLICATION_TYPE, AFFILIATION, ORGANIZATION, STATUS
# 0.7218658924102783
# 0.5805979371070862
# --------------
# Number 99 most effective
# Columns: APPLICATION_TYPE, AFFILIATION, ORGANIZATION, STATUS, SPECIAL_CONSIDERATIONS
# 0.7218658924102783
# 0.5816676020622253
# --------------
# Number 100 most effective
# Columns: APPLICATION_TYPE, AFFILIATION, USE_CASE, STATUS, INCOME_AMT, SPECIAL_CONSIDERATIONS
# 0.7218658924102783
# 0.5765509009361267
# --------------
# Number 101 most effective
# Columns: APPLICATION_TYPE, AFFILIATION, CLASSIFICATION, USE_CASE, STATUS, ASK_AMT
# 0.7217492461204529
# 0.5698901414871216
# --------------
# Number 102 most effective
# Columns: APPLICATION_TYPE, AFFILIATION, CLASSIFICATION, SPECIAL_CONSIDERATIONS
# 0.7216326594352722
# 0.5718833208084106
# --------------
# Number 103 most effective
# Columns: APPLICATION_TYPE, AFFILIATION, ORGANIZATION
# 0.7212827801704407
# 0.582101047039032
# --------------
# Number 104 most effective
# Columns: APPLICATION_TYPE, AFFILIATION, CLASSIFICATION, USE_CASE, STATUS, SPECIAL_CONSIDERATIONS, ASK_AMT
# 0.72116619348526
# 0.5685200095176697
# --------------
# Number 105 most effective
# Columns: APPLICATION_TYPE, AFFILIATION, CLASSIFICATION
# 0.7209329605102539
# 0.5724273920059204
# --------------
# Number 106 most effective
# Columns: APPLICATION_TYPE, AFFILIATION, STATUS, SPECIAL_CONSIDERATIONS
# 0.7208163142204285
# 0.5859543085098267
# --------------
# Number 107 most effective
# Columns: APPLICATION_TYPE, AFFILIATION, CLASSIFICATION, STATUS, SPECIAL_CONSIDERATIONS
# 0.7208163142204285
# 0.5752936601638794
# --------------
# Number 108 most effective
# Columns: APPLICATION_TYPE, AFFILIATION, STATUS
# 0.7205830812454224
# 0.5856767892837524
# --------------
# Number 109 most effective
# Columns: APPLICATION_TYPE, AFFILIATION, CLASSIFICATION, USE_CASE, SPECIAL_CONSIDERATIONS
# 0.7205830812454224
# 0.5704723000526428
# --------------
# Number 110 most effective
# Columns: APPLICATION_TYPE, AFFILIATION, CLASSIFICATION, USE_CASE, STATUS, SPECIAL_CONSIDERATIONS
# 0.7205830812454224
# 0.5697973966598511
# --------------
# Number 111 most effective
# Columns: APPLICATION_TYPE, AFFILIATION, CLASSIFICATION, USE_CASE
# 0.7203498482704163
# 0.5708766579627991
# --------------
# Number 112 most effective
# Columns: APPLICATION_TYPE, AFFILIATION, USE_CASE, ORGANIZATION
# 0.7203498482704163
# 0.5791845321655273
# --------------
# Number 113 most effective
# Columns: APPLICATION_TYPE, AFFILIATION, USE_CASE, ORGANIZATION, SPECIAL_CONSIDERATIONS
# 0.7203498482704163
# 0.5768840909004211
# --------------
# Number 114 most effective
# Columns: APPLICATION_TYPE, AFFILIATION, USE_CASE, ORGANIZATION, STATUS, SPECIAL_CONSIDERATIONS
# 0.7203498482704163
# 0.5777103304862976
# --------------
# Number 115 most effective
# Columns: APPLICATION_TYPE, AFFILIATION, CLASSIFICATION, STATUS
# 0.7201166152954102
# 0.5731514096260071
# --------------
# Number 116 most effective
# Columns: APPLICATION_TYPE, AFFILIATION, USE_CASE, STATUS, SPECIAL_CONSIDERATIONS
# 0.719883382320404
# 0.5840594172477722
# --------------
# Number 117 most effective
# Columns: APPLICATION_TYPE, AFFILIATION, USE_CASE, STATUS, SPECIAL_CONSIDERATIONS, ASK_AMT
# 0.7197667360305786
# 0.5784110426902771
# --------------
# Number 118 most effective
# Columns: APPLICATION_TYPE, AFFILIATION, USE_CASE, ORGANIZATION, STATUS
# 0.719650149345398
# 0.5779216885566711
# --------------
# Number 119 most effective
# Columns: APPLICATION_TYPE, AFFILIATION, SPECIAL_CONSIDERATIONS
# 0.7195335030555725
# 0.5852620601654053
# --------------
# Number 120 most effective
# Columns: APPLICATION_TYPE, AFFILIATION, CLASSIFICATION, USE_CASE, SPECIAL_CONSIDERATIONS, ASK_AMT
# 0.7193002700805664
# 0.568365752696991
# --------------
# Number 121 most effective
# Columns: APPLICATION_TYPE, AFFILIATION, USE_CASE, STATUS
# 0.7191836833953857
# 0.5827232599258423
# --------------
# Number 122 most effective
# Columns: APPLICATION_TYPE, AFFILIATION
# 0.7190670371055603
# 0.5850537419319153
# --------------
# Number 123 most effective
# Columns: APPLICATION_TYPE, AFFILIATION, CLASSIFICATION, USE_CASE, STATUS
# 0.7186005711555481
# 0.5717783570289612
# --------------
# Number 124 most effective
# Columns: APPLICATION_TYPE, AFFILIATION, USE_CASE
# 0.718367338180542
# 0.5833916068077087
# --------------
# Number 125 most effective
# Columns: APPLICATION_TYPE, AFFILIATION, USE_CASE, SPECIAL_CONSIDERATIONS
# 0.7180175185203552
# 0.5826218128204346
# --------------
# Number 126 most effective
# Columns: APPLICATION_TYPE, AFFILIATION, USE_CASE, ASK_AMT
# 0.7174344062805176
# 0.5807251334190369
# --------------
# Number 127 most effective
# Columns: APPLICATION_TYPE, AFFILIATION, ORGANIZATION, SPECIAL_CONSIDERATIONS
# 0.7166180610656738
# 0.5815813541412354
# --------------
# Number 128 most effective
# Columns: AFFILIATION, CLASSIFICATION, USE_CASE, ORGANIZATION, INCOME_AMT, SPECIAL_CONSIDERATIONS
# 0.7109037637710571
# 0.5757561922073364
# --------------
# Number 129 most effective
# Columns: AFFILIATION, CLASSIFICATION, USE_CASE, ORGANIZATION, INCOME_AMT, SPECIAL_CONSIDERATIONS, ASK_AMT
# 0.7100874781608582
# 0.5764544606208801
# --------------
# Number 130 most effective
# Columns: AFFILIATION, CLASSIFICATION, USE_CASE, ORGANIZATION, STATUS, INCOME_AMT
# 0.7099708318710327
# 0.5760588645935059
# --------------
# Number 131 most effective
# Columns: AFFILIATION, CLASSIFICATION, USE_CASE, ORGANIZATION, INCOME_AMT, ASK_AMT
# 0.7077550888061523
# 0.5769414901733398
# --------------
# Number 132 most effective
# Columns: AFFILIATION, CLASSIFICATION, USE_CASE, ORGANIZATION, STATUS, INCOME_AMT, ASK_AMT
# 0.7072886228561401
# 0.5797631740570068
# --------------
# Number 133 most effective
# Columns: AFFILIATION, CLASSIFICATION, USE_CASE, ORGANIZATION, STATUS, ASK_AMT
# 0.7069388031959534
# 0.5808500051498413
# --------------
# Number 134 most effective
# Columns: AFFILIATION, CLASSIFICATION, USE_CASE, ORGANIZATION, STATUS, SPECIAL_CONSIDERATIONS, ASK_AMT
# 0.7058892250061035
# 0.5836471915245056
# --------------
# Number 135 most effective
# Columns: AFFILIATION, CLASSIFICATION, USE_CASE, ORGANIZATION
# 0.7046064138412476
# 0.5850276350975037
# --------------
# Number 136 most effective
# Columns: AFFILIATION, CLASSIFICATION, USE_CASE, ORGANIZATION, STATUS, INCOME_AMT, SPECIAL_CONSIDERATIONS, ASK_AMT
# 0.7044897675514221
# 0.5769822597503662
# --------------
# Number 137 most effective
# Columns: AFFILIATION, CLASSIFICATION, USE_CASE, ORGANIZATION, STATUS, INCOME_AMT, SPECIAL_CONSIDERATIONS
# 0.7043731808662415
# 0.5783402323722839
# --------------
# Number 138 most effective
# Columns: AFFILIATION, CLASSIFICATION, USE_CASE, ORGANIZATION, INCOME_AMT
# 0.7036734819412231
# 0.5811969637870789
# --------------
# Number 139 most effective
# Columns: AFFILIATION, CLASSIFICATION, USE_CASE, ORGANIZATION, STATUS, SPECIAL_CONSIDERATIONS
# 0.7028571367263794
# 0.5865919589996338
# --------------
# Number 140 most effective
# Columns: AFFILIATION, USE_CASE, ORGANIZATION, STATUS, INCOME_AMT, ASK_AMT
# 0.7020407915115356
# 0.5987308621406555
# --------------
# Number 141 most effective
# Columns: AFFILIATION, USE_CASE, ORGANIZATION, INCOME_AMT, SPECIAL_CONSIDERATIONS, ASK_AMT
# 0.7020407915115356
# 0.5985957384109497
# --------------
# Number 142 most effective
# Columns: AFFILIATION, CLASSIFICATION, USE_CASE, STATUS, INCOME_AMT
# 0.7013410925865173
# 0.5925969481468201
# --------------
# Number 143 most effective
# Columns: AFFILIATION, CLASSIFICATION, ORGANIZATION, INCOME_AMT
# 0.7011078596115112
# 0.5854161977767944
# --------------
# Number 144 most effective
# Columns: AFFILIATION, CLASSIFICATION, ORGANIZATION, STATUS, INCOME_AMT, SPECIAL_CONSIDERATIONS, ASK_AMT
# 0.7009912729263306
# 0.5854132175445557
# --------------
# Number 145 most effective
# Columns: AFFILIATION, CLASSIFICATION, USE_CASE, INCOME_AMT
# 0.700641393661499
# 0.593582034111023
# --------------
# Number 146 most effective
# Columns: AFFILIATION, USE_CASE, ORGANIZATION, STATUS, INCOME_AMT
# 0.700641393661499
# 0.5992268919944763
# --------------
# Number 147 most effective
# Columns: AFFILIATION, CLASSIFICATION, USE_CASE, INCOME_AMT, SPECIAL_CONSIDERATIONS
# 0.7005248069763184
# 0.5939571261405945
# --------------
# Number 148 most effective
# Columns: AFFILIATION, CLASSIFICATION, USE_CASE, STATUS, INCOME_AMT, ASK_AMT
# 0.7005248069763184
# 0.5963902473449707
# --------------
# Number 149 most effective
# Columns: AFFILIATION, USE_CASE, ORGANIZATION, STATUS, INCOME_AMT, SPECIAL_CONSIDERATIONS
# 0.7005248069763184
# 0.6014769077301025
# --------------
# Number 150 most effective
# Columns: AFFILIATION, CLASSIFICATION, USE_CASE, INCOME_AMT, ASK_AMT
# 0.7000582814216614
# 0.5928359627723694
# --------------
# Number 151 most effective
# Columns: AFFILIATION, USE_CASE, ORGANIZATION, STATUS, INCOME_AMT, SPECIAL_CONSIDERATIONS, ASK_AMT
# 0.7000582814216614
# 0.599057674407959
# --------------
# Number 152 most effective
# Columns: AFFILIATION, USE_CASE, ORGANIZATION, INCOME_AMT
# 0.6997084617614746
# 0.5989048480987549
# --------------
# Number 153 most effective
# Columns: AFFILIATION, CLASSIFICATION, USE_CASE, INCOME_AMT, SPECIAL_CONSIDERATIONS, ASK_AMT
# 0.6995918154716492
# 0.5929776430130005
# --------------
# Number 154 most effective
# Columns: AFFILIATION, USE_CASE, ORGANIZATION, STATUS, ASK_AMT
# 0.699125349521637
# 0.6022481918334961
# --------------
# Number 155 most effective
# Columns: AFFILIATION, USE_CASE, ORGANIZATION, INCOME_AMT, ASK_AMT
# 0.699125349521637
# 0.598248302936554
# --------------
# Number 156 most effective
# Columns: AFFILIATION, USE_CASE, ORGANIZATION, STATUS, SPECIAL_CONSIDERATIONS, ASK_AMT
# 0.699125349521637
# 0.6031706929206848
# --------------
# Number 157 most effective
# Columns: AFFILIATION, CLASSIFICATION, ORGANIZATION, STATUS, INCOME_AMT, SPECIAL_CONSIDERATIONS
# 0.6988921165466309
# 0.5878244638442993
# --------------
# Number 158 most effective
# Columns: AFFILIATION, CLASSIFICATION, USE_CASE, ORGANIZATION, SPECIAL_CONSIDERATIONS, ASK_AMT
# 0.6987755298614502
# 0.5856031775474548
# --------------
# Number 159 most effective
# Columns: AFFILIATION, CLASSIFICATION, ORGANIZATION, STATUS, INCOME_AMT, ASK_AMT
# 0.6987755298614502
# 0.5855898261070251
# --------------
# Number 160 most effective
# Columns: AFFILIATION, CLASSIFICATION, USE_CASE, ORGANIZATION, ASK_AMT
# 0.6986588835716248
# 0.5843353867530823
# --------------
# Number 161 most effective
# Columns: AFFILIATION, CLASSIFICATION, ORGANIZATION, INCOME_AMT, SPECIAL_CONSIDERATIONS
# 0.6984256505966187
# 0.5850613117218018
# --------------
# Number 162 most effective
# Columns: AFFILIATION, CLASSIFICATION, ORGANIZATION, INCOME_AMT, ASK_AMT
# 0.6984256505966187
# 0.5870541930198669
# --------------
# Number 163 most effective
# Columns: AFFILIATION, CLASSIFICATION, ORGANIZATION, INCOME_AMT, SPECIAL_CONSIDERATIONS, ASK_AMT
# 0.6984256505966187
# 0.5850520730018616
# --------------
# Number 164 most effective
# Columns: AFFILIATION, USE_CASE, ORGANIZATION, INCOME_AMT, SPECIAL_CONSIDERATIONS
# 0.6981924176216125
# 0.5994248390197754
# --------------
# Number 165 most effective
# Columns: AFFILIATION, USE_CASE, ORGANIZATION, SPECIAL_CONSIDERATIONS, ASK_AMT
# 0.6981924176216125
# 0.6020737290382385
# --------------
# Number 166 most effective
# Columns: AFFILIATION, USE_CASE, ORGANIZATION, ASK_AMT
# 0.6976093053817749
# 0.6011187434196472
# --------------
# Number 167 most effective
# Columns: AFFILIATION, CLASSIFICATION, STATUS, INCOME_AMT, ASK_AMT
# 0.6974927186965942
# 0.59439617395401
# --------------
# Number 168 most effective
# Columns: AFFILIATION, CLASSIFICATION, ORGANIZATION, STATUS, INCOME_AMT
# 0.6971428394317627
# 0.5861757397651672
# --------------
# Number 169 most effective
# Columns: AFFILIATION, CLASSIFICATION, USE_CASE, STATUS, INCOME_AMT, SPECIAL_CONSIDERATIONS, ASK_AMT
# 0.6971428394317627
# 0.5962192416191101
# --------------
# Number 170 most effective
# Columns: AFFILIATION, CLASSIFICATION, USE_CASE, SPECIAL_CONSIDERATIONS, ASK_AMT
# 0.697026252746582
# 0.6007119417190552
# --------------
# Number 171 most effective
# Columns: AFFILIATION, CLASSIFICATION, INCOME_AMT, ASK_AMT
# 0.6969096064567566
# 0.5959508419036865
# --------------
# Number 172 most effective
# Columns: AFFILIATION, USE_CASE, ORGANIZATION, STATUS
# 0.6966763734817505
# 0.6056692004203796
# --------------
# Number 173 most effective
# Columns: AFFILIATION, USE_CASE, ORGANIZATION, STATUS, SPECIAL_CONSIDERATIONS
# 0.6964431405067444
# 0.6070541143417358
# --------------
# Number 174 most effective
# Columns: AFFILIATION, USE_CASE, ORGANIZATION
# 0.6963265538215637
# 0.6056150197982788
# --------------
# Number 175 most effective
# Columns: AFFILIATION, CLASSIFICATION, ORGANIZATION, ASK_AMT
# 0.6963265538215637
# 0.5938433408737183
# --------------
# Number 176 most effective
# Columns: AFFILIATION, CLASSIFICATION, INCOME_AMT
# 0.6962099075317383
# 0.5964910387992859
# --------------
# Number 177 most effective
# Columns: AFFILIATION, CLASSIFICATION, USE_CASE, STATUS, SPECIAL_CONSIDERATIONS, ASK_AMT
# 0.6962099075317383
# 0.5996239185333252
# --------------
# Number 178 most effective
# Columns: AFFILIATION, USE_CASE, INCOME_AMT, ASK_AMT
# 0.6959766745567322
# 0.6100758910179138
# --------------
# Number 179 most effective
# Columns: AFFILIATION, ORGANIZATION, INCOME_AMT, SPECIAL_CONSIDERATIONS
# 0.6959766745567322
# 0.6037437319755554
# --------------
# Number 180 most effective
# Columns: AFFILIATION, ORGANIZATION, INCOME_AMT, SPECIAL_CONSIDERATIONS, ASK_AMT
# 0.6959766745567322
# 0.6037796139717102
# --------------
# Number 181 most effective
# Columns: AFFILIATION, USE_CASE, ORGANIZATION, SPECIAL_CONSIDERATIONS
# 0.6958600878715515
# 0.6069165468215942
# --------------
# Number 182 most effective
# Columns: AFFILIATION, ORGANIZATION, STATUS, INCOME_AMT, SPECIAL_CONSIDERATIONS, ASK_AMT
# 0.6958600878715515
# 0.6046457886695862
# --------------
# Number 183 most effective
# Columns: AFFILIATION, CLASSIFICATION, USE_CASE, ORGANIZATION, STATUS
# 0.6957434415817261
# 0.5856008529663086
# --------------
# Number 184 most effective
# Columns: AFFILIATION, CLASSIFICATION, USE_CASE, STATUS, INCOME_AMT, SPECIAL_CONSIDERATIONS
# 0.6957434415817261
# 0.596199095249176
# --------------
# Number 185 most effective
# Columns: AFFILIATION, ORGANIZATION, STATUS, INCOME_AMT
# 0.6952769756317139
# 0.6039422154426575
# --------------
# Number 186 most effective
# Columns: AFFILIATION, CLASSIFICATION, ORGANIZATION, SPECIAL_CONSIDERATIONS, ASK_AMT
# 0.6951603293418884
# 0.5909101963043213
# --------------
# Number 187 most effective
# Columns: AFFILIATION, CLASSIFICATION, ORGANIZATION, STATUS, SPECIAL_CONSIDERATIONS, ASK_AMT
# 0.6950437426567078
# 0.5912354588508606
# --------------
# Number 188 most effective
# Columns: AFFILIATION, CLASSIFICATION, STATUS, INCOME_AMT
# 0.6949270963668823
# 0.5965480804443359
# --------------
# Number 189 most effective
# Columns: AFFILIATION, CLASSIFICATION, ORGANIZATION, STATUS, ASK_AMT
# 0.6949270963668823
# 0.5947187542915344
# --------------
# Number 190 most effective
# Columns: AFFILIATION, USE_CASE, INCOME_AMT, SPECIAL_CONSIDERATIONS
# 0.6948105096817017
# 0.608889102935791
# --------------
# Number 191 most effective
# Columns: AFFILIATION, CLASSIFICATION, INCOME_AMT, SPECIAL_CONSIDERATIONS, ASK_AMT
# 0.6948105096817017
# 0.594697892665863
# --------------
# Number 192 most effective
# Columns: AFFILIATION, CLASSIFICATION, USE_CASE, ASK_AMT
# 0.6946938633918762
# 0.60186368227005
# --------------
# Number 193 most effective
# Columns: AFFILIATION, USE_CASE, SPECIAL_CONSIDERATIONS, ASK_AMT
# 0.6946938633918762
# 0.613219141960144
# --------------
# Number 194 most effective
# Columns: AFFILIATION, CLASSIFICATION, USE_CASE, STATUS, SPECIAL_CONSIDERATIONS
# 0.6946938633918762
# 0.6009966135025024
# --------------
# Number 195 most effective
# Columns: AFFILIATION, CLASSIFICATION, USE_CASE, STATUS, ASK_AMT
# 0.6945772767066956
# 0.6012277007102966
# --------------
# Number 196 most effective
# Columns: AFFILIATION, CLASSIFICATION, ORGANIZATION, STATUS, SPECIAL_CONSIDERATIONS
# 0.6945772767066956
# 0.59422767162323
# --------------
# Number 197 most effective
# Columns: AFFILIATION, USE_CASE, STATUS, INCOME_AMT, ASK_AMT
# 0.6945772767066956
# 0.6087652444839478
# --------------
# Number 198 most effective
# Columns: AFFILIATION, USE_CASE, STATUS, INCOME_AMT, SPECIAL_CONSIDERATIONS, ASK_AMT
# 0.6945772767066956
# 0.6099330186843872
# --------------
# Number 199 most effective
# Columns: AFFILIATION, CLASSIFICATION, STATUS, ASK_AMT
# 0.6944606304168701
# 0.5984880924224854
# --------------
# Number 200 most effective
# Columns: AFFILIATION, CLASSIFICATION, USE_CASE, ORGANIZATION, SPECIAL_CONSIDERATIONS
# 0.6944606304168701
# 0.5892915725708008
# --------------
# Number 201 most effective
# Columns: AFFILIATION, CLASSIFICATION, STATUS, INCOME_AMT, SPECIAL_CONSIDERATIONS
# 0.6944606304168701
# 0.5950812101364136
# --------------
# Number 202 most effective
# Columns: AFFILIATION, CLASSIFICATION, USE_CASE, SPECIAL_CONSIDERATIONS
# 0.6943440437316895
# 0.6017998456954956
# --------------
# Number 203 most effective
# Columns: AFFILIATION, CLASSIFICATION, ORGANIZATION, STATUS
# 0.6943440437316895
# 0.5945652723312378
# --------------
# Number 204 most effective
# Columns: AFFILIATION, USE_CASE, STATUS, INCOME_AMT
# 0.6943440437316895
# 0.6090621948242188
# --------------
# Number 205 most effective
# Columns: AFFILIATION, ORGANIZATION, STATUS, INCOME_AMT, ASK_AMT
# 0.6943440437316895
# 0.605282187461853
# --------------
# Number 206 most effective
# Columns: AFFILIATION, CLASSIFICATION, STATUS, INCOME_AMT, SPECIAL_CONSIDERATIONS, ASK_AMT
# 0.6943440437316895
# 0.5965261459350586
# --------------
# Number 207 most effective
# Columns: AFFILIATION, SPECIAL_CONSIDERATIONS, ASK_AMT
# 0.694227397441864
# 0.613930344581604
# --------------
# Number 208 most effective
# Columns: AFFILIATION, ORGANIZATION, INCOME_AMT, ASK_AMT
# 0.694227397441864
# 0.6043168306350708
# --------------
# Number 209 most effective
# Columns: AFFILIATION, STATUS, SPECIAL_CONSIDERATIONS, ASK_AMT
# 0.694227397441864
# 0.6144290566444397
# --------------
# Number 210 most effective
# Columns: AFFILIATION, USE_CASE, STATUS, INCOME_AMT, SPECIAL_CONSIDERATIONS
# 0.694227397441864
# 0.608583390712738
# --------------
# Number 211 most effective
# Columns: AFFILIATION, USE_CASE, INCOME_AMT, SPECIAL_CONSIDERATIONS, ASK_AMT
# 0.694227397441864
# 0.6092240214347839
# --------------
# Number 212 most effective
# Columns: AFFILIATION, CLASSIFICATION, ORGANIZATION
# 0.6941108107566833
# 0.5943884253501892
# --------------
# Number 213 most effective
# Columns: AFFILIATION, USE_CASE, INCOME_AMT
# 0.6941108107566833
# 0.6098031997680664
# --------------
# Number 214 most effective
# Columns: AFFILIATION, CLASSIFICATION, USE_CASE
# 0.6939941644668579
# 0.6015639305114746
# --------------
# Number 215 most effective
# Columns: AFFILIATION, INCOME_AMT, SPECIAL_CONSIDERATIONS
# 0.6939941644668579
# 0.6125355958938599
# --------------
# Number 216 most effective
# Columns: AFFILIATION, CLASSIFICATION, USE_CASE, STATUS
# 0.6939941644668579
# 0.601445734500885
# --------------
# Number 217 most effective
# Columns: AFFILIATION, CLASSIFICATION, INCOME_AMT, SPECIAL_CONSIDERATIONS
# 0.6939941644668579
# 0.59694904088974
# --------------
# Number 218 most effective
# Columns: AFFILIATION, ORGANIZATION, STATUS, SPECIAL_CONSIDERATIONS, ASK_AMT
# 0.6938775777816772
# 0.6109236478805542
# --------------
# Number 219 most effective
# Columns: AFFILIATION, USE_CASE, ASK_AMT
# 0.6937609314918518
# 0.611549973487854
# --------------
# Number 220 most effective
# Columns: AFFILIATION, USE_CASE, STATUS, SPECIAL_CONSIDERATIONS, ASK_AMT
# 0.6936442852020264
# 0.6127970814704895
# --------------
# Number 221 most effective
# Columns: AFFILIATION, CLASSIFICATION, ASK_AMT
# 0.6935276985168457
# 0.6009190082550049
# --------------
# Number 222 most effective
# Columns: AFFILIATION, ORGANIZATION, STATUS, ASK_AMT
# 0.6935276985168457
# 0.6063725352287292
# --------------
# Number 223 most effective
# Columns: AFFILIATION, STATUS, ASK_AMT
# 0.6932944655418396
# 0.6140245795249939
# --------------
# Number 224 most effective
# Columns: AFFILIATION, USE_CASE, STATUS, ASK_AMT
# 0.6932944655418396
# 0.6117787957191467
# --------------
# Number 225 most effective
# Columns: AFFILIATION, STATUS, INCOME_AMT, SPECIAL_CONSIDERATIONS
# 0.6932944655418396
# 0.6122186779975891
# --------------
# Number 226 most effective
# Columns: AFFILIATION, CLASSIFICATION, STATUS, SPECIAL_CONSIDERATIONS, ASK_AMT
# 0.6932944655418396
# 0.6000159382820129
# --------------
# Number 227 most effective
# Columns: AFFILIATION, CLASSIFICATION, ORGANIZATION, SPECIAL_CONSIDERATIONS
# 0.6931778192520142
# 0.5971872806549072
# --------------
# Number 228 most effective
# Columns: AFFILIATION, CLASSIFICATION, SPECIAL_CONSIDERATIONS, ASK_AMT
# 0.6930612325668335
# 0.601413905620575
# --------------
# Number 229 most effective
# Columns: AFFILIATION, ORGANIZATION, SPECIAL_CONSIDERATIONS, ASK_AMT
# 0.6930612325668335
# 0.6089162230491638
# --------------
# Number 230 most effective
# Columns: AFFILIATION, ORGANIZATION, STATUS, INCOME_AMT, SPECIAL_CONSIDERATIONS
# 0.6930612325668335
# 0.6043489575386047
# --------------
# Number 231 most effective
# Columns: AFFILIATION, STATUS, INCOME_AMT, SPECIAL_CONSIDERATIONS, ASK_AMT
# 0.6928279995918274
# 0.6138428449630737
# --------------
# Number 232 most effective
# Columns: AFFILIATION, ASK_AMT
# 0.692711353302002
# 0.6160930395126343
# --------------
# Number 233 most effective
# Columns: AFFILIATION, STATUS, INCOME_AMT, ASK_AMT
# 0.692711353302002
# 0.612343966960907
# --------------
# Number 234 most effective
# Columns: AFFILIATION, ORGANIZATION, ASK_AMT
# 0.6925947666168213
# 0.6070325374603271
# --------------
# Number 235 most effective
# Columns: AFFILIATION, STATUS, INCOME_AMT
# 0.6925947666168213
# 0.6144992709159851
# --------------
# Number 236 most effective
# Columns: AFFILIATION, INCOME_AMT
# 0.6923615336418152
# 0.6123261451721191
# --------------
# Number 237 most effective
# Columns: AFFILIATION, ORGANIZATION, INCOME_AMT
# 0.6923615336418152
# 0.6054497361183167
# --------------
# Number 238 most effective
# Columns: AFFILIATION, INCOME_AMT, SPECIAL_CONSIDERATIONS, ASK_AMT
# 0.6922448873519897
# 0.6123077869415283
# --------------
# Number 239 most effective
# Columns: AFFILIATION, INCOME_AMT, ASK_AMT
# 0.691895067691803
# 0.6125994324684143
# --------------
# Number 240 most effective
# Columns: AFFILIATION
# 0.6916618347167969
# 0.6184850931167603
# --------------
# Number 241 most effective
# Columns: AFFILIATION, CLASSIFICATION
# 0.6916618347167969
# 0.6029064059257507
# --------------
# Number 242 most effective
# Columns: AFFILIATION, USE_CASE
# 0.6916618347167969
# 0.6160861253738403
# --------------
# Number 243 most effective
# Columns: AFFILIATION, USE_CASE, SPECIAL_CONSIDERATIONS
# 0.6916618347167969
# 0.6157234311103821
# --------------
# Number 244 most effective
# Columns: AFFILIATION, STATUS
# 0.6915451884269714
# 0.6188333630561829
# --------------
# Number 245 most effective
# Columns: AFFILIATION, STATUS, SPECIAL_CONSIDERATIONS
# 0.6915451884269714
# 0.618698000907898
# --------------
# Number 246 most effective
# Columns: AFFILIATION, USE_CASE, STATUS, SPECIAL_CONSIDERATIONS
# 0.6915451884269714
# 0.6163249611854553
# --------------
# Number 247 most effective
# Columns: AFFILIATION, CLASSIFICATION, SPECIAL_CONSIDERATIONS
# 0.691428542137146
# 0.6038960814476013
# --------------
# Number 248 most effective
# Columns: AFFILIATION, USE_CASE, STATUS
# 0.691428542137146
# 0.6166584491729736
# --------------
# Number 249 most effective
# Columns: AFFILIATION, ORGANIZATION, STATUS
# 0.691428542137146
# 0.6118698120117188
# --------------
# Number 250 most effective
# Columns: AFFILIATION, ORGANIZATION, STATUS, SPECIAL_CONSIDERATIONS
# 0.691428542137146
# 0.6115484833717346
# --------------
# Number 251 most effective
# Columns: AFFILIATION, SPECIAL_CONSIDERATIONS
# 0.6910787224769592
# 0.6181867122650146
# --------------
# Number 252 most effective
# Columns: AFFILIATION, CLASSIFICATION, STATUS
# 0.6909620761871338
# 0.6031203269958496
# --------------
# Number 253 most effective
# Columns: AFFILIATION, ORGANIZATION, SPECIAL_CONSIDERATIONS
# 0.6909620761871338
# 0.6123732328414917
# --------------
# Number 254 most effective
# Columns: AFFILIATION, CLASSIFICATION, STATUS, SPECIAL_CONSIDERATIONS
# 0.690612256526947
# 0.6038774251937866
# --------------
# Number 255 most effective
# Columns: AFFILIATION, ORGANIZATION
# 0.6903790235519409
# 0.6122207641601562
# --------------
# Number 256 most effective
# Columns: APPLICATION_TYPE, CLASSIFICATION, USE_CASE, ORGANIZATION, INCOME_AMT, SPECIAL_CONSIDERATIONS
# 0.6594752073287964
# 0.6109710931777954
# --------------
# Number 257 most effective
# Columns: APPLICATION_TYPE, CLASSIFICATION, USE_CASE, ORGANIZATION, INCOME_AMT, SPECIAL_CONSIDERATIONS, ASK_AMT
# 0.6586589217185974
# 0.6104139685630798
# --------------
# Number 258 most effective
# Columns: APPLICATION_TYPE, CLASSIFICATION, USE_CASE, ORGANIZATION, INCOME_AMT
# 0.6580758094787598
# 0.6131510138511658
# --------------
# Number 259 most effective
# Columns: APPLICATION_TYPE, CLASSIFICATION, USE_CASE, ORGANIZATION, INCOME_AMT, ASK_AMT
# 0.6574926972389221
# 0.6119869351387024
# --------------
# Number 260 most effective
# Columns: APPLICATION_TYPE, CLASSIFICATION, USE_CASE, ORGANIZATION, STATUS, INCOME_AMT, ASK_AMT
# 0.6569096446037292
# 0.6141066551208496
# --------------
# Number 261 most effective
# Columns: APPLICATION_TYPE, CLASSIFICATION, USE_CASE, ORGANIZATION, STATUS, INCOME_AMT
# 0.6563265323638916
# 0.6098227500915527
# --------------
# Number 262 most effective
# Columns: APPLICATION_TYPE, CLASSIFICATION, USE_CASE, ORGANIZATION, STATUS, INCOME_AMT, SPECIAL_CONSIDERATIONS
# 0.6559766530990601
# 0.6133993268013
# --------------
# Number 263 most effective
# Columns: APPLICATION_TYPE, CLASSIFICATION, USE_CASE, ORGANIZATION, STATUS, SPECIAL_CONSIDERATIONS, ASK_AMT
# 0.655743420124054
# 0.615979015827179
# --------------
# Number 264 most effective
# Columns: APPLICATION_TYPE, CLASSIFICATION, USE_CASE, ORGANIZATION, STATUS, ASK_AMT
# 0.6555101871490479
# 0.6152562499046326
# --------------
# Number 265 most effective
# Columns: APPLICATION_TYPE, CLASSIFICATION, ORGANIZATION, STATUS, INCOME_AMT, ASK_AMT
# 0.6537609100341797
# 0.6163777112960815
# --------------
# Number 266 most effective
# Columns: APPLICATION_TYPE, CLASSIFICATION, ORGANIZATION, STATUS, INCOME_AMT
# 0.653644323348999
# 0.6166437268257141
# --------------
# Number 267 most effective
# Columns: APPLICATION_TYPE, CLASSIFICATION, USE_CASE, ORGANIZATION, SPECIAL_CONSIDERATIONS, ASK_AMT
# 0.6534110903739929
# 0.6162503957748413
# --------------
# Number 268 most effective
# Columns: APPLICATION_TYPE, CLASSIFICATION, ORGANIZATION, STATUS, INCOME_AMT, SPECIAL_CONSIDERATIONS
# 0.6531778573989868
# 0.6174980998039246
# --------------
# Number 269 most effective
# Columns: APPLICATION_TYPE, CLASSIFICATION, ORGANIZATION, STATUS, INCOME_AMT, SPECIAL_CONSIDERATIONS, ASK_AMT
# 0.6530612111091614
# 0.6175711154937744
# --------------
# Number 270 most effective
# Columns: APPLICATION_TYPE, CLASSIFICATION, USE_CASE, ORGANIZATION, ASK_AMT
# 0.6529446244239807
# 0.6178053617477417
# --------------
# Number 271 most effective
# Columns: APPLICATION_TYPE, CLASSIFICATION, ORGANIZATION, INCOME_AMT, SPECIAL_CONSIDERATIONS, ASK_AMT
# 0.6529446244239807
# 0.6191790103912354
# --------------
# Number 272 most effective
# Columns: APPLICATION_TYPE, CLASSIFICATION, ORGANIZATION, SPECIAL_CONSIDERATIONS, ASK_AMT
# 0.6528279781341553
# 0.6213281750679016
# --------------
# Number 273 most effective
# Columns: APPLICATION_TYPE, CLASSIFICATION, USE_CASE, ORGANIZATION, STATUS, INCOME_AMT, SPECIAL_CONSIDERATIONS, ASK_AMT
# 0.6527113914489746
# 0.6126115918159485
# --------------
# Number 274 most effective
# Columns: APPLICATION_TYPE, CLASSIFICATION, ORGANIZATION, INCOME_AMT
# 0.6524781584739685
# 0.6158449649810791
# --------------
# Number 275 most effective
# Columns: APPLICATION_TYPE, CLASSIFICATION, USE_CASE, ORGANIZATION, STATUS, SPECIAL_CONSIDERATIONS
# 0.652128279209137
# 0.6158291101455688
# --------------
# Number 276 most effective
# Columns: APPLICATION_TYPE, CLASSIFICATION, USE_CASE, ORGANIZATION, STATUS
# 0.6516618132591248
# 0.6172153353691101
# --------------
# Number 277 most effective
# Columns: APPLICATION_TYPE, CLASSIFICATION, USE_CASE, ORGANIZATION
# 0.6515451669692993
# 0.6174463629722595
# --------------
# Number 278 most effective
# Columns: APPLICATION_TYPE, CLASSIFICATION, ORGANIZATION, INCOME_AMT, SPECIAL_CONSIDERATIONS
# 0.650845468044281
# 0.617743968963623
# --------------
# Number 279 most effective
# Columns: APPLICATION_TYPE, CLASSIFICATION, ORGANIZATION, STATUS, SPECIAL_CONSIDERATIONS, ASK_AMT
# 0.6507288813591003
# 0.6210763454437256
# --------------
# Number 280 most effective
# Columns: APPLICATION_TYPE, CLASSIFICATION, ORGANIZATION, INCOME_AMT, ASK_AMT
# 0.649329423904419
# 0.6171274781227112
# --------------
# Number 281 most effective
# Columns: APPLICATION_TYPE, CLASSIFICATION, ORGANIZATION, STATUS, ASK_AMT
# 0.64851313829422
# 0.6239901781082153
# --------------
# Number 282 most effective
# Columns: APPLICATION_TYPE, CLASSIFICATION, ORGANIZATION, SPECIAL_CONSIDERATIONS
# 0.6483964920043945
# 0.626231849193573
# --------------
# Number 283 most effective
# Columns: APPLICATION_TYPE, CLASSIFICATION, ORGANIZATION, STATUS, SPECIAL_CONSIDERATIONS
# 0.6474635601043701
# 0.622987687587738
# --------------
# Number 284 most effective
# Columns: APPLICATION_TYPE, CLASSIFICATION, ORGANIZATION, STATUS
# 0.6471136808395386
# 0.6234785318374634
# --------------
# Number 285 most effective
# Columns: APPLICATION_TYPE, CLASSIFICATION, ORGANIZATION
# 0.6467638611793518
# 0.6233305335044861
# --------------
# Number 286 most effective
# Columns: APPLICATION_TYPE, CLASSIFICATION, USE_CASE, ORGANIZATION, SPECIAL_CONSIDERATIONS
# 0.6448979377746582
# 0.6202074289321899
# --------------
# Number 287 most effective
# Columns: APPLICATION_TYPE, CLASSIFICATION, ORGANIZATION, ASK_AMT
# 0.6423323750495911
# 0.6223537921905518
# --------------
# Number 288 most effective
# Columns: CLASSIFICATION, USE_CASE, ORGANIZATION, STATUS, INCOME_AMT
# 0.6383673548698425
# 0.632034420967102
# --------------
# Number 289 most effective
# Columns: CLASSIFICATION, USE_CASE, ORGANIZATION, INCOME_AMT, ASK_AMT
# 0.6383673548698425
# 0.6323069930076599
# --------------
# Number 290 most effective
# Columns: CLASSIFICATION, USE_CASE, ORGANIZATION, INCOME_AMT, SPECIAL_CONSIDERATIONS, ASK_AMT
# 0.6379008889198303
# 0.6333662271499634
# --------------
# Number 291 most effective
# Columns: CLASSIFICATION, USE_CASE, ORGANIZATION, STATUS, INCOME_AMT, SPECIAL_CONSIDERATIONS, ASK_AMT
# 0.6374344229698181
# 0.6320757865905762
# --------------
# Number 292 most effective
# Columns: CLASSIFICATION, USE_CASE, ORGANIZATION, STATUS, INCOME_AMT, ASK_AMT
# 0.636734664440155
# 0.6321586966514587
# --------------
# Number 293 most effective
# Columns: APPLICATION_TYPE, USE_CASE, ORGANIZATION, INCOME_AMT
# 0.6361516118049622
# 0.6386298537254333
# --------------
# Number 294 most effective
# Columns: CLASSIFICATION, USE_CASE, ORGANIZATION, INCOME_AMT
# 0.6361516118049622
# 0.6335508227348328
# --------------
# Number 295 most effective
# Columns: APPLICATION_TYPE, USE_CASE, ORGANIZATION, STATUS, INCOME_AMT, SPECIAL_CONSIDERATIONS
# 0.6360349655151367
# 0.639265775680542
# --------------
# Number 296 most effective
# Columns: APPLICATION_TYPE, USE_CASE, ORGANIZATION, INCOME_AMT, SPECIAL_CONSIDERATIONS
# 0.6358017325401306
# 0.6386134028434753
# --------------
# Number 297 most effective
# Columns: APPLICATION_TYPE, USE_CASE, ORGANIZATION, INCOME_AMT, SPECIAL_CONSIDERATIONS, ASK_AMT
# 0.6354519128799438
# 0.6390042304992676
# --------------
# Number 298 most effective
# Columns: APPLICATION_TYPE, USE_CASE, ORGANIZATION, STATUS, INCOME_AMT, SPECIAL_CONSIDERATIONS, ASK_AMT
# 0.6348688006401062
# 0.6396052241325378
# --------------
# Number 299 most effective
# Columns: CLASSIFICATION, USE_CASE, ORGANIZATION, INCOME_AMT, SPECIAL_CONSIDERATIONS
# 0.6347522139549255
# 0.6342774629592896
# --------------
# Number 300 most effective
# Columns: CLASSIFICATION, USE_CASE, ORGANIZATION, STATUS, INCOME_AMT, SPECIAL_CONSIDERATIONS
# 0.6347522139549255
# 0.6334678530693054
# --------------
# Number 301 most effective
# Columns: CLASSIFICATION, USE_CASE, ORGANIZATION, STATUS, SPECIAL_CONSIDERATIONS, ASK_AMT
# 0.6347522139549255
# 0.6379210948944092
# --------------
# Number 302 most effective
# Columns: APPLICATION_TYPE, USE_CASE, ORGANIZATION, STATUS, INCOME_AMT, ASK_AMT
# 0.6342856884002686
# 0.6381868720054626
# --------------
# Number 303 most effective
# Columns: APPLICATION_TYPE, USE_CASE, ORGANIZATION, INCOME_AMT, ASK_AMT
# 0.6339358687400818
# 0.6397988200187683
# --------------
# Number 304 most effective
# Columns: APPLICATION_TYPE, USE_CASE, ORGANIZATION, STATUS, INCOME_AMT
# 0.6328862905502319
# 0.6401532292366028
# --------------
# Number 305 most effective
# Columns: APPLICATION_TYPE, USE_CASE, ORGANIZATION, ASK_AMT
# 0.6324198246002197
# 0.6414468288421631
# --------------
# Number 306 most effective
# Columns: CLASSIFICATION, USE_CASE, ORGANIZATION, STATUS, ASK_AMT
# 0.6320699453353882
# 0.6387621760368347
# --------------
# Number 307 most effective
# Columns: APPLICATION_TYPE, ORGANIZATION, INCOME_AMT, SPECIAL_CONSIDERATIONS
# 0.6319533586502075
# 0.6437628269195557
# --------------
# Number 308 most effective
# Columns: APPLICATION_TYPE, ORGANIZATION, STATUS, INCOME_AMT, ASK_AMT
# ...
# Columns: USE_CASE, ORGANIZATION, STATUS, ASK_AMT
# 0.608746349811554
# 0.6672767400741577
# --------------
# Number 389 most effective
# Columns: USE_CASE, ORGANIZATION, STATUS, INCOME_AMT, SPECIAL_CONSIDERATIONS
# 0.6086297631263733
# 0.664300262928009
# --------------
# Number 390 most effective
# Columns: USE_CASE, ORGANIZATION, STATUS, SPECIAL_CONSIDERATIONS, ASK_AMT
# 0.6085131168365479
# 0.6667079925537109
# --------------
# Number 391 most effective
# Columns: USE_CASE, ORGANIZATION, STATUS, INCOME_AMT
# 0.6083965301513672
# 0.6644852757453918
# --------------
# Number 392 most effective
# Columns: USE_CASE, ORGANIZATION, INCOME_AMT, SPECIAL_CONSIDERATIONS
# 0.6083965301513672
# 0.6644042730331421
# --------------
# Number 393 most effective
# Columns: USE_CASE, ORGANIZATION, INCOME_AMT, SPECIAL_CONSIDERATIONS, ASK_AMT
# 0.6083965301513672
# 0.6650377511978149
# --------------
# Number 394 most effective
# Columns: USE_CASE, ORGANIZATION, SPECIAL_CONSIDERATIONS, ASK_AMT
# 0.6079300045967102
# 0.6674076318740845
# --------------
# Number 395 most effective
# Columns: APPLICATION_TYPE, CLASSIFICATION, USE_CASE
# 0.6062973737716675
# 0.645684540271759
# --------------
# Number 396 most effective
# Columns: ORGANIZATION, INCOME_AMT, ASK_AMT
# 0.6055976748466492
# 0.6683342456817627
# --------------
# Number 397 most effective
# Columns: ORGANIZATION, INCOME_AMT
# 0.6054810285568237
# 0.668289065361023
# --------------
# Number 398 most effective
# Columns: ORGANIZATION, ASK_AMT
# 0.6054810285568237
# 0.6699322462081909
# --------------
# Number 399 most effective
# Columns: ORGANIZATION, STATUS, INCOME_AMT, ASK_AMT
# 0.6053644418716431
# 0.6680960059165955
# --------------
# Number 400 most effective
# Columns: ORGANIZATION, STATUS, INCOME_AMT, SPECIAL_CONSIDERATIONS
# 0.6052477955818176
# 0.6678714156150818
# --------------
# Number 401 most effective
# Columns: ORGANIZATION, INCOME_AMT, SPECIAL_CONSIDERATIONS, ASK_AMT
# 0.6052477955818176
# 0.6686326265335083
# --------------
# Number 402 most effective
# Columns: ORGANIZATION, STATUS, INCOME_AMT
# 0.605131208896637
# 0.6677569150924683
# --------------
# Number 403 most effective
# Columns: ORGANIZATION, SPECIAL_CONSIDERATIONS, ASK_AMT
# 0.6050145626068115
# 0.670231282711029
# --------------
# Number 404 most effective
# Columns: ORGANIZATION, STATUS, ASK_AMT
# 0.6048979759216309
# 0.6708596348762512
# --------------
# Number 405 most effective
# Columns: ORGANIZATION, STATUS, INCOME_AMT, SPECIAL_CONSIDERATIONS, ASK_AMT
# 0.6048979759216309
# 0.6679617166519165
# --------------
# Number 406 most effective
# Columns: ORGANIZATION, STATUS, SPECIAL_CONSIDERATIONS, ASK_AMT
# 0.6047813296318054
# 0.6700657606124878
# --------------
# Number 407 most effective
# Columns: USE_CASE, ORGANIZATION
# 0.603848397731781
# 0.6684153079986572
# --------------
# Number 408 most effective
# Columns: USE_CASE, ORGANIZATION, STATUS
# 0.6037317514419556
# 0.6691875457763672
# --------------
# Number 409 most effective
# Columns: USE_CASE, ORGANIZATION, SPECIAL_CONSIDERATIONS
# 0.6037317514419556
# 0.6687246561050415
# --------------
# Number 410 most effective
# Columns: USE_CASE, ORGANIZATION, STATUS, SPECIAL_CONSIDERATIONS
# 0.6036151647567749
# 0.6690914630889893
# --------------
# Number 411 most effective
# Columns: ORGANIZATION, INCOME_AMT, SPECIAL_CONSIDERATIONS
# 0.6022157669067383
# 0.6693862080574036
# --------------
# Number 412 most effective
# Columns: ORGANIZATION
# 0.6000000238418579
# 0.6719745993614197
# --------------
# Number 413 most effective
# Columns: ORGANIZATION, STATUS
# 0.5998833775520325
# 0.6722542643547058
# --------------
# Number 414 most effective
# Columns: ORGANIZATION, SPECIAL_CONSIDERATIONS
# 0.5998833775520325
# 0.6724947690963745
# --------------
# Number 415 most effective
# Columns: ORGANIZATION, STATUS, SPECIAL_CONSIDERATIONS
# 0.5997667908668518
# 0.672158420085907
# --------------
# Number 416 most effective
# Columns: CLASSIFICATION, USE_CASE, INCOME_AMT, ASK_AMT
# 0.5986005663871765
# 0.6604506373405457
# --------------
# Number 417 most effective
# Columns: CLASSIFICATION, USE_CASE, STATUS, INCOME_AMT
# 0.5983673334121704
# 0.6603280305862427
# --------------
# Number 418 most effective
# Columns: CLASSIFICATION, USE_CASE, STATUS, INCOME_AMT, SPECIAL_CONSIDERATIONS, ASK_AMT
# 0.5979008674621582
# 0.661052405834198
# --------------
# Number 419 most effective
# Columns: CLASSIFICATION, USE_CASE, INCOME_AMT, SPECIAL_CONSIDERATIONS, ASK_AMT
# 0.5977842807769775
# 0.6605930924415588
# --------------
# Number 420 most effective
# Columns: CLASSIFICATION, USE_CASE, STATUS, INCOME_AMT, SPECIAL_CONSIDERATIONS
# 0.5976676344871521
# 0.6609627604484558
# --------------
# Number 421 most effective
# Columns: CLASSIFICATION, USE_CASE, INCOME_AMT, SPECIAL_CONSIDERATIONS
# 0.5955685377120972
# 0.6602575778961182
# --------------
# Number 422 most effective
# Columns: CLASSIFICATION, USE_CASE, INCOME_AMT
# 0.5949854254722595
# 0.660171627998352
# --------------
# Number 423 most effective
# Columns: CLASSIFICATION, USE_CASE, STATUS, INCOME_AMT, ASK_AMT
# 0.5949854254722595
# 0.661823570728302
# --------------
# Number 424 most effective
# Columns: CLASSIFICATION, INCOME_AMT, ASK_AMT
# 0.5888046622276306
# 0.6658368706703186
# --------------
# Number 425 most effective
# Columns: CLASSIFICATION, STATUS, INCOME_AMT, ASK_AMT
# 0.5888046622276306
# 0.6661520004272461
# --------------
# Number 426 most effective
# Columns: CLASSIFICATION, STATUS, INCOME_AMT, SPECIAL_CONSIDERATIONS, ASK_AMT
# 0.5888046622276306
# 0.666054904460907
# --------------
# Number 427 most effective
# Columns: CLASSIFICATION, INCOME_AMT, SPECIAL_CONSIDERATIONS, ASK_AMT
# 0.5884547829627991
# 0.6677115559577942
# --------------
# Number 428 most effective
# Columns: CLASSIFICATION, STATUS, INCOME_AMT
# 0.5883381962776184
# 0.6657864451408386
# --------------
# Number 429 most effective
# Columns: CLASSIFICATION, INCOME_AMT
# 0.588221549987793
# 0.667005181312561
# --------------
# Number 430 most effective
# Columns: CLASSIFICATION, STATUS, INCOME_AMT, SPECIAL_CONSIDERATIONS
# 0.588221549987793
# 0.6664007306098938
# --------------
# Number 431 most effective
# Columns: CLASSIFICATION, USE_CASE, SPECIAL_CONSIDERATIONS, ASK_AMT
# 0.5857725739479065
# 0.666137158870697
# --------------
# Number 432 most effective
# Columns: APPLICATION_TYPE, USE_CASE, INCOME_AMT, SPECIAL_CONSIDERATIONS
# 0.5843731760978699
# 0.6577463150024414
# --------------
# Number 433 most effective
# Columns: APPLICATION_TYPE, USE_CASE, STATUS, INCOME_AMT, SPECIAL_CONSIDERATIONS
# 0.5843731760978699
# 0.6576457023620605
# --------------
# Number 434 most effective
# Columns: APPLICATION_TYPE, USE_CASE, SPECIAL_CONSIDERATIONS, ASK_AMT
# 0.5841399431228638
# 0.6605749130249023
# --------------
# Number 435 most effective
# Columns: APPLICATION_TYPE, USE_CASE, INCOME_AMT, SPECIAL_CONSIDERATIONS, ASK_AMT
# 0.5841399431228638
# 0.6573368310928345
# --------------
# Number 436 most effective
# Columns: APPLICATION_TYPE, USE_CASE, STATUS, INCOME_AMT, SPECIAL_CONSIDERATIONS, ASK_AMT
# 0.5841399431228638
# 0.6584649682044983
# --------------
# Number 437 most effective
# Columns: APPLICATION_TYPE, USE_CASE, INCOME_AMT
# 0.5837900638580322
# 0.6569850444793701
# --------------
# Number 438 most effective
# Columns: APPLICATION_TYPE, USE_CASE, STATUS, SPECIAL_CONSIDERATIONS, ASK_AMT
# 0.5837900638580322
# 0.6609262824058533
# --------------
# Number 439 most effective
# Columns: APPLICATION_TYPE, USE_CASE, STATUS, INCOME_AMT
# 0.5835568308830261
# 0.6585379242897034
# --------------
# Number 440 most effective
# Columns: APPLICATION_TYPE, USE_CASE, INCOME_AMT, ASK_AMT
# 0.5835568308830261
# 0.6575854420661926
# --------------
# Number 441 most effective
# Columns: CLASSIFICATION, USE_CASE, STATUS
# 0.58332359790802
# 0.6673952341079712
# --------------
# Number 442 most effective
# Columns: APPLICATION_TYPE, USE_CASE, STATUS, INCOME_AMT, ASK_AMT
# 0.5828571319580078
# 0.6584243178367615
# --------------
# Number 443 most effective
# Columns: CLASSIFICATION, USE_CASE
# 0.582507312297821
# 0.6673676371574402
# --------------
# Number 444 most effective
# Columns: CLASSIFICATION, USE_CASE, STATUS, ASK_AMT
# 0.5823906660079956
# 0.6670187711715698
# --------------
# Number 445 most effective
# Columns: CLASSIFICATION, USE_CASE, STATUS, SPECIAL_CONSIDERATIONS, ASK_AMT
# 0.5822740793228149
# 0.6676327586174011
# --------------
# Number 446 most effective
# Columns: APPLICATION_TYPE, USE_CASE, ASK_AMT
# 0.5816909670829773
# 0.6611342430114746
# --------------
# Number 447 most effective
# Columns: CLASSIFICATION, USE_CASE, ASK_AMT
# 0.5811078548431396
# 0.6666264533996582
# --------------
# Number 448 most effective
# Columns: CLASSIFICATION, STATUS, ASK_AMT
# 0.5811078548431396
# 0.6710125803947449
# --------------
# Number 449 most effective
# Columns: APPLICATION_TYPE, USE_CASE, SPECIAL_CONSIDERATIONS
# 0.5799416899681091
# 0.6608232259750366
# --------------
# Number 450 most effective
# Columns: CLASSIFICATION, USE_CASE, STATUS, SPECIAL_CONSIDERATIONS
# 0.5799416899681091
# 0.6670876145362854
# --------------
# Number 451 most effective
# Columns: APPLICATION_TYPE, USE_CASE, STATUS, ASK_AMT
# 0.579708456993103
# 0.6609700322151184
# --------------
# Number 452 most effective
# Columns: CLASSIFICATION, INCOME_AMT, SPECIAL_CONSIDERATIONS
# 0.5795918107032776
# 0.6670523881912231
# --------------
# Number 453 most effective
# Columns: CLASSIFICATION, SPECIAL_CONSIDERATIONS, ASK_AMT
# 0.5791253447532654
# 0.6719074845314026
# --------------
# Number 454 most effective
# Columns: APPLICATION_TYPE, USE_CASE
# 0.5785422921180725
# 0.6613326072692871
# --------------
# Number 455 most effective
# Columns: CLASSIFICATION
# 0.5784256458282471
# 0.6718921065330505
# --------------
# Number 456 most effective
# Columns: APPLICATION_TYPE, USE_CASE, STATUS, SPECIAL_CONSIDERATIONS
# 0.5784256458282471
# 0.6619298458099365
# --------------
# Number 457 most effective
# Columns: CLASSIFICATION, STATUS
# 0.5783090591430664
# 0.6716368794441223
# --------------
# Number 458 most effective
# Columns: CLASSIFICATION, SPECIAL_CONSIDERATIONS
# 0.5783090591430664
# 0.6719022393226624
# --------------
# Number 459 most effective
# Columns: APPLICATION_TYPE, STATUS, INCOME_AMT, ASK_AMT
# 0.5783090591430664
# 0.6629694700241089
# --------------
# Number 460 most effective
# Columns: APPLICATION_TYPE, USE_CASE, STATUS
# 0.578192412853241
# 0.6615839004516602
# --------------
# Number 461 most effective
# Columns: APPLICATION_TYPE, SPECIAL_CONSIDERATIONS, ASK_AMT
# 0.578192412853241
# 0.6666463613510132
# --------------
# Number 462 most effective
# Columns: CLASSIFICATION, STATUS, SPECIAL_CONSIDERATIONS
# 0.578192412853241
# 0.6718699336051941
# --------------
# Number 463 most effective
# Columns: APPLICATION_TYPE, STATUS, SPECIAL_CONSIDERATIONS, ASK_AMT
# 0.578192412853241
# 0.6669546961784363
# --------------
# Number 464 most effective
# Columns: APPLICATION_TYPE, STATUS, INCOME_AMT, SPECIAL_CONSIDERATIONS, ASK_AMT
# 0.578192412853241
# 0.6636185050010681
# --------------
# Number 465 most effective
# Columns: APPLICATION_TYPE, ASK_AMT
# 0.5780758261680603
# 0.6665555834770203
# --------------
# Number 466 most effective
# Columns: APPLICATION_TYPE, STATUS, INCOME_AMT
# 0.5780758261680603
# 0.6633286476135254
# --------------
# Number 467 most effective
# Columns: APPLICATION_TYPE, INCOME_AMT, SPECIAL_CONSIDERATIONS
# 0.5778425931930542
# 0.6639533638954163
# --------------
# Number 468 most effective
# Columns: APPLICATION_TYPE, STATUS, INCOME_AMT, SPECIAL_CONSIDERATIONS
# 0.5778425931930542
# 0.663541316986084
# --------------
# Number 469 most effective
# Columns: APPLICATION_TYPE, STATUS, ASK_AMT
# 0.5777259469032288
# 0.6672612428665161
# --------------
# Number 470 most effective
# Columns: APPLICATION_TYPE, INCOME_AMT, SPECIAL_CONSIDERATIONS, ASK_AMT
# 0.5773760676383972
# 0.6632657051086426
# --------------
# Number 471 most effective
# Columns: APPLICATION_TYPE, INCOME_AMT
# 0.5771428346633911
# 0.6637462973594666
# --------------
# Number 472 most effective
# Columns: APPLICATION_TYPE, INCOME_AMT, ASK_AMT
# 0.5771428346633911
# 0.6627964973449707
# --------------
# Number 473 most effective
# Columns: CLASSIFICATION, USE_CASE, SPECIAL_CONSIDERATIONS
# 0.5755102038383484
# 0.6668427586555481
# --------------
# Number 474 most effective
# Columns: APPLICATION_TYPE
# 0.5720116496086121
# 0.6677144169807434
# --------------
# Number 475 most effective
# Columns: APPLICATION_TYPE, STATUS
# 0.5720116496086121
# 0.6677950024604797
# --------------
# Number 476 most effective
# Columns: APPLICATION_TYPE, SPECIAL_CONSIDERATIONS
# 0.5720116496086121
# 0.668258786201477
# --------------
# Number 477 most effective
# Columns: APPLICATION_TYPE, STATUS, SPECIAL_CONSIDERATIONS
# 0.5720116496086121
# 0.6682551503181458
# --------------
# Number 478 most effective
# Columns: CLASSIFICATION, STATUS, SPECIAL_CONSIDERATIONS, ASK_AMT
# 0.5683965086936951
# 0.6713590025901794
# --------------
# Number 479 most effective
# Columns: CLASSIFICATION, ASK_AMT
# 0.5666472315788269
# 0.6718122959136963
# --------------
# Number 480 most effective
# Columns: USE_CASE, INCOME_AMT, SPECIAL_CONSIDERATIONS, ASK_AMT
# 0.5467055439949036
# 0.6850051283836365
# --------------
# Number 481 most effective
# Columns: USE_CASE, INCOME_AMT, SPECIAL_CONSIDERATIONS
# 0.5465888977050781
# 0.685413658618927
# --------------
# Number 482 most effective
# Columns: USE_CASE, STATUS, INCOME_AMT, SPECIAL_CONSIDERATIONS, ASK_AMT
# 0.5465888977050781
# 0.6847577691078186
# --------------
# Number 483 most effective
# Columns: USE_CASE, INCOME_AMT
# 0.546355664730072
# 0.684986412525177
# --------------
# Number 484 most effective
# Columns: USE_CASE, STATUS, INCOME_AMT
# 0.5462390780448914
# 0.6850493550300598
# --------------
# Number 485 most effective
# Columns: USE_CASE, INCOME_AMT, ASK_AMT
# 0.5456559658050537
# 0.686109721660614
# --------------
# Number 486 most effective
# Columns: USE_CASE, STATUS, INCOME_AMT, ASK_AMT
# 0.5451894998550415
# 0.6851542592048645
# --------------
# Number 487 most effective
# Columns: USE_CASE, STATUS, INCOME_AMT, SPECIAL_CONSIDERATIONS
# 0.5419241786003113
# 0.6862385272979736
# --------------
# Number 488 most effective
# Columns: USE_CASE, ASK_AMT
# 0.541224479675293
# 0.6888055801391602
# --------------
# Number 489 most effective
# Columns: USE_CASE, SPECIAL_CONSIDERATIONS, ASK_AMT
# 0.5406414270401001
# 0.688753068447113
# --------------
# Number 490 most effective
# Columns: USE_CASE, STATUS, ASK_AMT
# 0.5402915477752686
# 0.6886604428291321
# --------------
# Number 491 most effective
# Columns: USE_CASE, STATUS, SPECIAL_CONSIDERATIONS, ASK_AMT
# 0.5395918488502502
# 0.6888433694839478
# --------------
# Number 492 most effective
# Columns: USE_CASE
# 0.5353935956954956
# 0.6901988983154297
# --------------
# Number 493 most effective
# Columns: USE_CASE, SPECIAL_CONSIDERATIONS
# 0.5353935956954956
# 0.6899680495262146
# --------------
# Number 494 most effective
# Columns: USE_CASE, STATUS
# 0.5352769494056702
# 0.6900343894958496
# --------------
# Number 495 most effective
# Columns: USE_CASE, STATUS, SPECIAL_CONSIDERATIONS
# 0.5352769494056702
# 0.6900033950805664
# --------------
# Number 496 most effective
# Columns: INCOME_AMT
# 0.5345772504806519
# 0.6877385973930359
# --------------
# Number 497 most effective
# Columns: STATUS, INCOME_AMT
# 0.5345772504806519
# 0.6876561045646667
# --------------
# Number 498 most effective
# Columns: INCOME_AMT, SPECIAL_CONSIDERATIONS
# 0.5345772504806519
# 0.6878141760826111
# --------------
# Number 499 most effective
# Columns: INCOME_AMT, ASK_AMT
# 0.5345772504806519
# 0.6879328489303589
# --------------
# Number 500 most effective
# Columns: STATUS, INCOME_AMT, SPECIAL_CONSIDERATIONS
# 0.5345772504806519
# 0.6883302927017212
# --------------
# Number 501 most effective
# Columns: STATUS, INCOME_AMT, ASK_AMT
# 0.5345772504806519
# 0.6875948309898376
# --------------
# Number 502 most effective
# Columns: INCOME_AMT, SPECIAL_CONSIDERATIONS, ASK_AMT
# 0.5345772504806519
# 0.687744140625
# --------------
# Number 503 most effective
# Columns: STATUS, INCOME_AMT, SPECIAL_CONSIDERATIONS, ASK_AMT
# 0.5345772504806519
# 0.6877726912498474
# --------------
# Number 504 most effective
# Columns: STATUS, ASK_AMT
# 0.5343440175056458
# 0.6907240748405457
# --------------
# Number 505 most effective
# Columns: ASK_AMT
# 0.5342274308204651
# 0.690667986869812
# --------------
# Number 506 most effective
# Columns: SPECIAL_CONSIDERATIONS, ASK_AMT
# 0.533994197845459
# 0.6906958222389221
# --------------
# Number 507 most effective
# Columns: STATUS, SPECIAL_CONSIDERATIONS, ASK_AMT
# 0.533994197845459
# 0.690830647945404
# --------------
# Number 508 most effective
# Columns: STATUS
# 0.5292128324508667
# 0.691440761089325
# --------------
# Number 509 most effective
# Columns: SPECIAL_CONSIDERATIONS
# 0.5292128324508667
# 0.6914844512939453
# --------------
# Number 510 most effective
# Columns: STATUS, SPECIAL_CONSIDERATIONS
# 0.5292128324508667
# 0.691452145576477
# --------------

# %%
# Do once more on the full feature set to test its comparative accuracy
application_df = create_app_df(all_cols)

model_summary = { 'cols': application_df.columns }

# Split our preprocessed data into our features and target arrays
features = application_df.drop("IS_SUCCESSFUL", axis=1)
target = application_df["IS_SUCCESSFUL"]

# Split the preprocessed data into a training and testing dataset
X_train, X_test, y_train, y_test = train_test_split(features, target, random_state=1)

# Create a StandardScaler instance
# Fit the StandardScaler
X_scaler = StandardScaler().fit(X_train)

# Scale the data
X_train_scaled = X_scaler.transform(X_train)
X_test_scaled = X_scaler.transform(X_test)

model = create_model(len(features.columns))

# Train the model
history = model.fit(
    X_train_scaled,
    y_train,
    epochs=34,
    verbose=0
    )

model_loss, model_accuracy = model.evaluate(X_test_scaled,y_test,verbose=2)
print(f"Loss: {model_loss}, Accuracy: {model_accuracy}")
# Out:
# 268/268 - 0s - loss: 0.5588 - accuracy: 0.7269 - 424ms/epoch - 2ms/step
# Loss: 0.5587639212608337, Accuracy: 0.7268804907798767

# %% [markdown]
# # Analysis
#
# The most important thing here, I think, is the test I did as an afterthought: the test to recreate my tuning results. The full feature set, using the same neural network parameters, produced almost an entire percent lower accuracy, here, than it did during tuning. This says, to me, that any tuning gains were mostly random chance, and that I need to tune again using different feature sets.
#
# The following features are needed for obtaining the highest effective accuracy, given the neural network parameters obtained from AlphabetSoupCharity_Tuning: APPLICATION_TYPE, AFFILIATION, CLASSIFICATION, ORGANIZATION, INCOME_AMT. However, due to my findings concerning the outweighted importance of random chance, I feel I should ignore the single highest grouping and instead take the features from the top 10 feature sets
#
# * APPLICATION_TYPE - 10 times
# * AFFILIATION - 10 times
# * CLASSIFICATION - 10 times
# * USE_CASE - 3 times
# * ORGANIZATION - 10 times
# * STATUS - 2 times
# * INCOME_AMT - 8 times
# * SPECIAL_CONSIDERATIONS - 5 times
# * ASK_AMT - 6 times
#
# From these top 10 numbers, I can glean the following:
#
# * APPLICATION_TYPE, AFFILIATION, CLASSIFICATION, and ORGANIZATION are obviously critical features, as they are present in every one of the top 10
# * INCOME_AMT is also very important to successful training
# * STATUS and USE_CASE are practically inconsequential
# * I'm left to decide for ASK_AMT and SPECIAL_CONSIDERATIONS
#
# Since I want those features which are correlated most highly with accuracy, I will go with APPLICATION_TYPE, AFFILIATION, CLASSIFICATION, ORGANIZATION, and INCOME_AMT. The others' correlation is just too low for me to be happy with their influence. (Incidentally, this happens to be the feature set that gave me the highest accuracy here, though I don't know whether or not that means much)
#
# Since the accuracies here are rather low, compared to the Tuning notebook, I'm going to try tuning again, but first I want to try feature tweaking again, this time on the number of values collapsed into the Other categories. That will be done in AlphabetSoupCharity_FeatureTweaksPt2
